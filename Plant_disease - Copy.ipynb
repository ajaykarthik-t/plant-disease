# %%
import os
import pathlib
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import shutil
import random
import tensorflow as tf
from tensorflow import keras
import tensorflow_hub as hub
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPool2D, Dense, Flatten, Dropout, BatchNormalization, GlobalAveragePooling2D, Activation, GlobalMaxPool2D, BatchNormalization
from tensorflow.keras.optimizers import Adam, Nadam
from tensorflow.keras import Input, Model
from tensorflow.keras.utils import plot_model
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
import splitfolders
# Out:
# WARNING:tensorflow:From C:\Users\ajayk\anaconda3\envs\py310\lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
# splits dataset it into three subfolders: train, val (validation), and test.

splitfolders.ratio(r"C:\Users\ajayk\Desktop\InnoProjects\SRIT\Plant_Disease\Datasett", output="output",
    seed=1337, ratio=(.75, .2, .05), group_prefix=None, move=False)
# Out:
# Copying files: 9446 files [00:12, 772.94 files/s]

# %%
data_dir = pathlib.Path('output/')
train_dir = 'output/train'
val_dir = 'output/val'
test_dir = 'output/test'

# %%
class_name = np.array(sorted([item.name for item in data_dir.glob("*")]))
print(class_name)
# Out:
# ['test' 'train' 'val']

# %%
for dirpath, dirnames, filenames in os.walk('output'):
  print(f"{len(dirnames)} folder and {len(filenames)} images in {dirpath}")
# Out:
# 3 folder and 0 images in output
# 13 folder and 0 images in output\test
# 0 folder and 32 images in output\test\Apple___Apple_scab
# 0 folder and 32 images in output\test\Apple___Black_rot
# 0 folder and 14 images in output\test\Apple___Cedar_apple_rust
# 0 folder and 83 images in output\test\Apple___healthy
# 0 folder and 76 images in output\test\Blueberry___healthy
# 0 folder and 44 images in output\test\Cherry_(including_sour)___healthy
# 0 folder and 53 images in output\test\Cherry_(including_sour)___Powdery_mildew
# 0 folder and 27 images in output\test\Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot
# 0 folder and 60 images in output\test\Corn_(maize)___Common_rust_
# 0 folder and 59 images in output\test\Corn_(maize)___healthy
# 0 folder and 3 images in output\test\Healthy
# 0 folder and 3 images in output\test\Powdery
# 0 folder and 3 images in output\test\Rust
# 13 folder and 0 images in output\train
# 0 folder and 472 images in output\train\Apple___Apple_scab
# 0 folder and 465 images in output\train\Apple___Black_rot
# 0 folder and 206 images in output\train\Apple___Cedar_apple_rust
# 0 folder and 1233 images in output\train\Apple___healthy
# 0 folder and 1126 images in output\train\Blueberry___healthy
# 0 folder and 640 images in output\train\Cherry_(including_sour)___healthy
# 0 folder and 789 images in output\train\Cherry_(including_sour)___Powdery_mildew
# 0 folder and 384 images in output\train\Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot
# 0 folder and 894 images in output\train\Corn_(maize)___Common_rust_
# 0 folder and 871 images in output\train\Corn_(maize)___healthy
# 0 folder and 37 images in output\train\Healthy
# 0 folder and 37 images in output\train\Powdery
# 0 folder and 37 images in output\train\Rust
# 13 folder and 0 images in output\val
# 0 folder and 126 images in output\val\Apple___Apple_scab
# 0 folder and 124 images in output\val\Apple___Black_rot
# 0 folder and 55 images in output\val\Apple___Cedar_apple_rust
# 0 folder and 329 images in output\val\Apple___healthy
# 0 folder and 300 images in output\val\Blueberry___healthy
# 0 folder and 170 images in output\val\Cherry_(including_sour)___healthy
# 0 folder and 210 images in output\val\Cherry_(including_sour)___Powdery_mildew
# 0 folder and 102 images in output\val\Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot
# 0 folder and 238 images in output\val\Corn_(maize)___Common_rust_
# 0 folder and 232 images in output\val\Corn_(maize)___healthy
# 0 folder and 10 images in output\val\Healthy
# 0 folder and 10 images in output\val\Powdery
# 0 folder and 10 images in output\val\Rust

# %%
def view_random_image(target_dir, target_class):
    target_folder = target_dir + target_class
    random_image = random.sample(os.listdir(target_folder), 1)
    img = mpimg.imread(target_folder + "/" + random_image[0])
    plt.imshow(img)
    plt.title(target_class)
    plt.axis("off")
    
    print(f"Image Shape : {img.shape}")
    plt.show()

# %%
for i in range(1,2):
    img_n = view_random_image(target_dir='output/train/', target_class='Apple___Apple_scab')
# Out:
# Image Shape : (256, 256, 3)

# %%
for i in range(1,2):
    img_n = view_random_image(target_dir='output/train/', target_class='Apple___Black_rot')
# Out:
# Image Shape : (256, 256, 3)

# %%
for i in range(1,2):
    img_n = view_random_image(target_dir='output/train/', target_class='Apple___Cedar_apple_rust')
# Out:
# Image Shape : (256, 256, 3)

# %%
for i in range(1,2):
    img_n = view_random_image(target_dir='output/train/', target_class='Apple___healthy')
# Out:
# Image Shape : (256, 256, 3)

# %%
for i in range(1,2):
    img_n = view_random_image(target_dir='output/train/', target_class='Blueberry___healthy')
# Out:
# Image Shape : (256, 256, 3)

# %%
for i in range(1,2):
    img_n = view_random_image(target_dir='output/train/', target_class='Cherry_(including_sour)___healthy')
# Out:
# Image Shape : (256, 256, 3)

# %%
for i in range(1,2):
    img_n = view_random_image(target_dir='output/train/', target_class='Cherry_(including_sour)___Powdery_mildew')
# Out:
# Image Shape : (256, 256, 3)

# %%
for i in range(1,2):
    img_n = view_random_image(target_dir='output/train/', target_class='Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot')
# Out:
# Image Shape : (256, 256, 3)

# %%
for i in range(1,2):
    img_n = view_random_image(target_dir='output/train/', target_class='Corn_(maize)___Common_rust_')
# Out:
# Image Shape : (256, 256, 3)

# %%
for i in range(1,2):
    img_n = view_random_image(target_dir='output/train/', target_class='Corn_(maize)___healthy')
# Out:
# Image Shape : (256, 256, 3)

# %%
# Sets the global random seed.
tf.random.set_seed(46)

# preprocess data
train_datagen = ImageDataGenerator(rescale=1/255.0,
                                   rotation_range=0.2,
                                   zoom_range=0.2,
                                   width_shift_range=0.2,
                                   height_shift_range=0.2,
                                   vertical_flip=True,
                                   horizontal_flip=True)
valid_datagen = ImageDataGenerator(rescale=1/255.0)
test_datagen = ImageDataGenerator(rescale=1/255.0)

# %%
train_data = train_datagen.flow_from_directory(train_dir,
                                               batch_size=64,
                                               target_size=(224, 224),
                                               class_mode='categorical',
                                               shuffle=True,
                                               seed=46)

valid_data = valid_datagen.flow_from_directory(val_dir,
                                               batch_size=64,
                                               target_size=(224, 224),
                                               class_mode='categorical',
                                               shuffle=False,
                                               seed=46)

test_data = test_datagen.flow_from_directory(test_dir,
                                               batch_size=64,
                                               target_size=(224, 224),
                                               class_mode='categorical',
                                               shuffle=False,
                                               seed=46)
# Out:
# Found 7191 images belonging to 13 classes.
# Found 1916 images belonging to 13 classes.
# Found 489 images belonging to 13 classes.

# %%
train_data.class_indices
# Out:
# {'Apple___Apple_scab': 0,
#  'Apple___Black_rot': 1,
#  'Apple___Cedar_apple_rust': 2,
#  'Apple___healthy': 3,
#  'Blueberry___healthy': 4,
#  'Cherry_(including_sour)___Powdery_mildew': 5,
#  'Cherry_(including_sour)___healthy': 6,
#  'Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot': 7,
#  'Corn_(maize)___Common_rust_': 8,
#  'Corn_(maize)___healthy': 9,
#  'Healthy': 10,
#  'Powdery': 11,
#  'Rust': 12}

# %%
train_y=train_data.classes
val_y=valid_data.classes
test_y=test_data.classes

# %%
print("train_y.shape: ", train_y.shape)
print("val_y.shape: ", val_y.shape)
print("test_y.shape: ", test_y.shape)
# Out:
# train_y.shape:  (7191,)
# val_y.shape:  (1916,)
# test_y.shape:  (489,)

# %%
base_model = tf.keras.applications.DenseNet121(input_shape=(224, 224, 3),
                                                        include_top=False,
                                                        weights='imagenet')
base_model.trainable = False

# %%
global_average_layer = GlobalAveragePooling2D()
prediction_layer = Dense(13)
softmax = Activation('softmax')

inputs = Input(shape=(224, 224, 3))
x = base_model(inputs, training=False)
x = Dropout(0.25)(x)
x = global_average_layer(x)
outputs = prediction_layer(x)
outputs = softmax(outputs)

model = Model(inputs, outputs)

# %%
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ densenet121 (Functional)        │ (None, 7, 7, 1024)     │     7,037,504 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 7, 7, 1024)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 1024)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 13)             │        13,325 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 13)             │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 7,050,829 (26.90 MB)
#  Trainable params: 13,325 (52.05 KB)
#  Non-trainable params: 7,037,504 (26.85 MB)

# %%
plot_model(model, show_shapes=True)
# Out:
# You must install graphviz (see instructions at https://graphviz.gitlab.io/download/) for `plot_model` to work.

# %%
model.compile(loss='categorical_crossentropy',
              optimizer=Adam(learning_rate=0.001),
              metrics=['accuracy'])

# train model
history = model.fit(train_data, epochs=50, validation_data=valid_data)
# Out:
# Epoch 1/50
# C:\Users\ajayk\anaconda3\envs\py310\lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:120: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 42s 16s/step - accuracy: 0.3346 - loss: 1.2595 - val_accuracy: 0.3667 - val_loss: 1.1466
# Epoch 2/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 23s 10s/step - accuracy: 0.2653 - loss: 1.2151 - val_accuracy: 0.4667 - val_loss: 1.0825
# Epoch 3/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 19s 9s/step - accuracy: 0.4121 - loss: 1.0921 - val_accuracy: 0.4000 - val_loss: 1.0336
# Epoch 4/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 19s 8s/step - accuracy: 0.4383 - loss: 1.1181 - val_accuracy: 0.4667 - val_loss: 0.9737
# Epoch 5/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 19s 8s/step - accuracy: 0.4793 - loss: 1.0354 - val_accuracy: 0.6667 - val_loss: 0.9268
# Epoch 6/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 23s 10s/step - accuracy: 0.4782 - loss: 1.0209 - val_accuracy: 0.6000 - val_loss: 0.8785
# Epoch 7/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 24s 11s/step - accuracy: 0.5322 - loss: 0.9242 - val_accuracy: 0.6000 - val_loss: 0.8308
# Epoch 8/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 20s 9s/step - accuracy: 0.6223 - loss: 0.8711 - val_accuracy: 0.6667 - val_loss: 0.7817
# Epoch 9/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 19s 7s/step - accuracy: 0.6099 - loss: 0.8764 - val_accuracy: 0.8000 - val_loss: 0.7244
# Epoch 10/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 18s 8s/step - accuracy: 0.7184 - loss: 0.8247 - val_accuracy: 0.7667 - val_loss: 0.6750
# Epoch 11/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 19s 7s/step - accuracy: 0.6760 - loss: 0.7845 - val_accuracy: 0.7667 - val_loss: 0.6389
# Epoch 12/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 17s 6s/step - accuracy: 0.6856 - loss: 0.7953 - val_accuracy: 0.8333 - val_loss: 0.6072
# Epoch 13/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 17s 7s/step - accuracy: 0.7860 - loss: 0.6633 - val_accuracy: 0.8333 - val_loss: 0.5777
# Epoch 14/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 18s 7s/step - accuracy: 0.7657 - loss: 0.7034 - val_accuracy: 0.8333 - val_loss: 0.5514
# Epoch 15/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 19s 9s/step - accuracy: 0.8543 - loss: 0.6721 - val_accuracy: 0.8333 - val_loss: 0.5307
# Epoch 16/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 18s 8s/step - accuracy: 0.8019 - loss: 0.6333 - val_accuracy: 0.8000 - val_loss: 0.5167
# Epoch 17/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 18s 8s/step - accuracy: 0.8294 - loss: 0.6252 - val_accuracy: 0.8333 - val_loss: 0.4991
# Epoch 18/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 17s 8s/step - accuracy: 0.8433 - loss: 0.5569 - val_accuracy: 0.8333 - val_loss: 0.4776
# Epoch 19/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 19s 9s/step - accuracy: 0.8624 - loss: 0.5377 - val_accuracy: 0.8333 - val_loss: 0.4545
# Epoch 20/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 19s 8s/step - accuracy: 0.8270 - loss: 0.5628 - val_accuracy: 0.8333 - val_loss: 0.4358
# Epoch 21/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 16s 7s/step - accuracy: 0.8674 - loss: 0.5594 - val_accuracy: 0.9000 - val_loss: 0.4212
# Epoch 22/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 18s 7s/step - accuracy: 0.9191 - loss: 0.5001 - val_accuracy: 0.9000 - val_loss: 0.4080
# Epoch 23/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 19s 8s/step - accuracy: 0.8819 - loss: 0.5042 - val_accuracy: 0.9000 - val_loss: 0.3973
# Epoch 24/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 18s 7s/step - accuracy: 0.8923 - loss: 0.4843 - val_accuracy: 0.9000 - val_loss: 0.3882
# Epoch 25/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 16s 8s/step - accuracy: 0.8663 - loss: 0.5030 - val_accuracy: 0.9000 - val_loss: 0.3806
# Epoch 26/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 18s 7s/step - accuracy: 0.8923 - loss: 0.4553 - val_accuracy: 0.9000 - val_loss: 0.3744
# Epoch 27/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 18s 8s/step - accuracy: 0.8843 - loss: 0.4717 - val_accuracy: 0.9000 - val_loss: 0.3657
# Epoch 28/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 19s 7s/step - accuracy: 0.8959 - loss: 0.4562 - val_accuracy: 0.9000 - val_loss: 0.3578
# Epoch 29/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 19s 8s/step - accuracy: 0.9137 - loss: 0.4676 - val_accuracy: 0.9000 - val_loss: 0.3468
# Epoch 30/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 20s 9s/step - accuracy: 0.9131 - loss: 0.4125 - val_accuracy: 0.9000 - val_loss: 0.3394
# Epoch 31/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 20s 8s/step - accuracy: 0.9147 - loss: 0.4249 - val_accuracy: 0.9000 - val_loss: 0.3357
# Epoch 32/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 20s 8s/step - accuracy: 0.8946 - loss: 0.3931 - val_accuracy: 0.9000 - val_loss: 0.3311
# Epoch 33/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 19s 7s/step - accuracy: 0.9415 - loss: 0.3949 - val_accuracy: 0.9000 - val_loss: 0.3282
# Epoch 34/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 18s 6s/step - accuracy: 0.9543 - loss: 0.3690 - val_accuracy: 0.9000 - val_loss: 0.3257
# Epoch 35/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 18s 8s/step - accuracy: 0.8985 - loss: 0.4089 - val_accuracy: 0.9000 - val_loss: 0.3231
# Epoch 36/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 17s 8s/step - accuracy: 0.9067 - loss: 0.3819 - val_accuracy: 0.9000 - val_loss: 0.3153
# Epoch 37/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 19s 8s/step - accuracy: 0.9259 - loss: 0.3482 - val_accuracy: 0.9000 - val_loss: 0.3054
# Epoch 38/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 20s 7s/step - accuracy: 0.9199 - loss: 0.3727 - val_accuracy: 0.9000 - val_loss: 0.2973
# Epoch 39/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 19s 7s/step - accuracy: 0.9307 - loss: 0.3635 - val_accuracy: 0.9000 - val_loss: 0.2925
# Epoch 40/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 17s 7s/step - accuracy: 0.8914 - loss: 0.3621 - val_accuracy: 0.9000 - val_loss: 0.2890
# Epoch 41/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 17s 7s/step - accuracy: 0.9296 - loss: 0.3705 - val_accuracy: 0.9000 - val_loss: 0.2870
# Epoch 42/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 18s 8s/step - accuracy: 0.9319 - loss: 0.3749 - val_accuracy: 0.9000 - val_loss: 0.2865
# Epoch 43/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 19s 8s/step - accuracy: 0.9191 - loss: 0.3318 - val_accuracy: 0.9000 - val_loss: 0.2852
# Epoch 44/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 21s 7s/step - accuracy: 0.9139 - loss: 0.3584 - val_accuracy: 0.9000 - val_loss: 0.2825
# Epoch 45/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 19s 9s/step - accuracy: 0.8914 - loss: 0.3998 - val_accuracy: 0.9000 - val_loss: 0.2790
# Epoch 46/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 17s 6s/step - accuracy: 0.9139 - loss: 0.3355 - val_accuracy: 0.9000 - val_loss: 0.2745
# Epoch 47/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 17s 6s/step - accuracy: 0.9147 - loss: 0.3589 - val_accuracy: 0.9000 - val_loss: 0.2722
# Epoch 48/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 17s 6s/step - accuracy: 0.9311 - loss: 0.3309 - val_accuracy: 0.9000 - val_loss: 0.2705
# Epoch 49/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 17s 6s/step - accuracy: 0.9483 - loss: 0.2884 - val_accuracy: 0.9000 - val_loss: 0.2680
# Epoch 50/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 16s 6s/step - accuracy: 0.9371 - loss: 0.3027 - val_accuracy: 0.9000 - val_loss: 0.2675

# %%
model.save('my_model.keras')

# %%
def plot_loss_curves(history):
  loss = history.history['loss']
  val_loss = history.history['val_loss']

  accuracy = history.history['accuracy']
  val_accuracy = history.history['val_accuracy']

  epochs = range(len(loss))

  plt.plot(epochs, loss, label='training_loss')
  plt.plot(epochs, val_loss, label='val_loss')
  plt.title("Loss Curves")
  plt.xlabel("Epochs")
  plt.legend()

  plt.figure()
  plt.plot(epochs, accuracy, label='training_accuracy')
  plt.plot(epochs, val_accuracy, label='val_accuracy')
  plt.title("Accuracy Curves")
  plt.xlabel("Epochs")
  plt.legend()

# %%
plot_loss_curves(history)

# %%
val_pred = model.predict(valid_data)
val_pred = val_pred.argmax(axis=1)
print(classification_report(val_pred, val_y))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 7s 7s/step
#               precision    recall  f1-score   support
#
#            0       1.00      0.83      0.91        12
#            1       0.90      1.00      0.95         9
#            2       0.80      0.89      0.84         9
#
#     accuracy                           0.90        30
#    macro avg       0.90      0.91      0.90        30
# weighted avg       0.91      0.90      0.90        30

# %%
cfm_val = confusion_matrix(val_pred, val_y)
ax = sns.heatmap(cfm_val, annot=True, 
            cmap='Blues')

# Preparation for plotting confusion matrix
ax.set_title('Confusion Matrix with labels\n\n');
ax.set_xlabel('\nPredicted Values')
ax.set_ylabel('Actual Values ');

# Display the visualization of the Confusion Matrix.
plt.show()

# %%
test_pred = model.predict(test_data)
test_pred = test_pred.argmax(axis=1)
print(classification_report(test_pred, test_y))
# Out:
# C:\Users\ajayk\anaconda3\envs\py310\lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:120: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         3
#            1       1.00      1.00      1.00         3
#            2       1.00      1.00      1.00         3
#
#     accuracy                           1.00         9
#    macro avg       1.00      1.00      1.00         9
# weighted avg       1.00      1.00      1.00         9

# %%
cfm_test = confusion_matrix(test_pred, test_y)
ax = sns.heatmap(cfm_test, annot=True, 
            cmap='Blues')

# Preparation for plotting confusion matrix
ax.set_title('Confusion Matrix with labels\n\n');
ax.set_xlabel('\nPredicted Values')
ax.set_ylabel('Actual Values ');

# Display the visualization of the Confusion Matrix.
plt.show()

# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\ajayk\anaconda3\envs\py310\lib\site-packages (4.9.0.80)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\ajayk\anaconda3\envs\py310\lib\site-packages (from opencv-python) (1.26.4)

# %%
import matplotlib.pyplot as plt
from keras.models import load_model
from tensorflow.keras.preprocessing import image
import numpy as np

# Load the trained model
model = load_model('my_model.keras')

# Load the image
image_path = r"C:\Users\ajayk\Desktop\InnoProjects\SRIT\Plant_Disease\output\val\Powdery\9f802f3f8a603cb5.jpg"
image = image.load_img(image_path, target_size=(224, 224))

# Preprocess the image
img = np.array(image)
img = img / 255.0
img = img.reshape(1, 224, 224, 3)

# Predict the label
label = model.predict(img)

# Determine the predicted class
class_names = ['Apple___Apple_scab', 'Apple___Black_rot', 'Apple___Cedar_apple_rust', 'Apple___healthy', 'Blueberry___healthy','Cherry_(including_sour)___healthy','Cherry_(including_sour)___Powdery_mildew','Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot','Corn_(maize)___Common_rust_','Corn_(maize)___healthy','Healthy','Powdery','Rust' ]
predicted_class_index = np.argmax(label)
predicted_class = class_names[predicted_class_index]

# Causes and fixes for different diseases
causes_and_fixes = {
    'Healthy': {
        'Cause': "No disease detected. The plant is healthy.",
        'Fix': "Maintain current care routines to keep the plant healthy."
    },
    'Powdery': {
        'Cause': "Caused by high humidity and poor air circulation, which encourage fungal spores to thrive.",
        'Fix': "Improve air circulation around the plant and avoid overhead watering. Apply fungicides if needed."
    },
    'Rust': {
        'Cause': "Triggered by wet conditions and prolonged leaf wetness, which promote fungal growth.",
        'Fix': "Remove affected leaves and avoid wetting leaves during watering. Use fungicides to prevent further spread."
    }
}

# Print the predicted class with cause and fix
print(f"Predicted Class: {predicted_class}")
print(f"Cause: {causes_and_fixes[predicted_class]['Cause']}")
print(f"Fix: {causes_and_fixes[predicted_class]['Fix']}")

# Display the image with the predicted label
plt.imshow(image)
plt.title(predicted_class)
plt.axis('off')
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# Predicted Class: Powdery
